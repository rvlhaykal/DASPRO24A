# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

bulan = ['Januari','Februari','Maret','April','Mei','Juni','Juli','Agustus','September','Oktober','November','Desember']

#Pengeluaran antara 500.000 - 2.000.000

Minggu_1 = np.random.randint(500000,2000001,12)
Minggu_2 = np.random.randint(500000,2000001,12)
Minggu_3 = np.random.randint(500000,2000001,12)
Minggu_4 = np.random.randint(500000,2000001,12)

data = {
    'Bulan' : bulan,
    'Minggu_1' : Minggu_1,
    'Minggu_2' : Minggu_2,
    'Minggu_3' : Minggu_3,
    'Minggu_4' : Minggu_4
}

df = pd.DataFrame(data)

df['Total_Pengeluaran'] = df[['Minggu_1','Minggu_2','Minggu_3','Minggu_4']].sum(axis=1)
df
# Out:
#         Bulan  Minggu_1  Minggu_2  Minggu_3  Minggu_4  Total_Pengeluaran
# 0     Januari   1474746    571286    558912   1890051            4494995
# 1    Februari    635233   1387718   1724195    842895            4590041
# 2       Maret   1659944    718589    927994   1037314            4343841
# 3       April   1414129   1432368   1010018   1566438            5422953
# 4         Mei   1542985   1660785    799415   1109054            5112239
# 5        Juni    882975   1051236    930584   1542807            4407602
# 6        Juli   1121091   1710598   1563193   1569004            5963886
# 7     Agustus   1506998   1828481    946857   1428692            5711028
# 8   September   1419968   1738432   1322106    921591            5402097
# 9     Oktober   1250192   1131239   1539084    628399            4548914
# 10   November   1219499   1560682    872734   1673152            5326067
# 11   Desember   1503437    781287   1487927    741800            4514451

# %%
#Total Pengeluaran PEr Bulan -> BAR

plt.figure(figsize =(12,6))#Canvas dengan ukuran width,height (inch)
plt.title('Total Pengeluaran Per Bulan')
plt.bar(df['Bulan'],df['Total_Pengeluaran'],color='black')
plt.xticks(rotation=45)
plt.ylabel("Rupiah")
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %%
#Scatter Plot untuk analisa data pengeluaran per minggu per bulan
plt.figure(figsize=(12,6))
for minggu in ['Minggu_1','Minggu_2','Minggu_3','Minggu_4']:
    plt.plot(df['Bulan'],df[minggu],marker='o',label=minggu)

plt.title("Pengeluaran Per Minggu")
plt.xlabel('Bulan')
plt.ylabel('Pengeluaran(Rupiah)')
plt.legend()
plt.tight_layout()
plt.show()

# %%
#Pie Chart -> Prosentase
plt.figure(figsize=(10,10))
plt.pie(df['Total_Pengeluaran'],labels=df['Bulan'],startangle=90,autopct='%1.1f%%')
plt.axis('equal')
plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
from sklearn.linear_model import LinearRegression

df['Bulan_Angka'] = np.arange(1,13)

x = df[['Bulan_Angka']]
y = df['Total_Pengeluaran']

model = LinearRegression()

model.fit(x,y)

prediksi = model.predict([[13]])[0]
print(f"Hasil Prediksi Adalah :{prediksi:,.0f}")
# Out:
# Hasil Prediksi Adalah :5,248,376
# C:\Users\komputer 12\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
df = pd.read_csv('data kecelakaan di kabupaten cirebon.csv')
df
# Out:
#    id  kode_provinsi nama_provinsi  kode_kabupaten_kota nama_kabupaten_kota  \
# 0   1             32    JAWA BARAT                 3209   KABUPATEN CIREBON
# 1   2             32    JAWA BARAT                 3209   KABUPATEN CIREBON
# 2   3             32    JAWA BARAT                 3209   KABUPATEN CIREBON
# 3   4             32    JAWA BARAT                 3209   KABUPATEN CIREBON
# 4   5             32    JAWA BARAT                 3209   KABUPATEN CIREBON
#
#                kategori_korban  jumlah_korban  satuan  tahun
# 0  KORBAN LAKA MENINGGAL DUNIA            201   ORANG   2022
# 1       KORBAN LAKA LUKA BERAT              3   ORANG   2022
# 2      KORBAN LAKA LUKA RINGAN            959   ORANG   2022
# 3              KERUGIAN MATERI     1232051200  RUPIAH   2022
# 4           JUMLAH LAKA LANTAS            835   KASUS   2022

# %%
print("""
    Data Kecelakaan Lalu Lintas di Kabupaten Cirebon Tahun 2022
    
    1.Korban Meninggal Dunia sebanyak 201 orang
    2.Luka berat hanya 3 orang
    3.Kebanyakan hanya luka ringan saja berjumlah 959 orang
    4.Kerugian Materi mencapai Rp. 1.232.051.200
    5.Jumlah Kasus Laka Lantas Berjumlah 835 Kasus
""")
# Out:
#     Data Kecelakaan Lalu Lintas di Kabupaten Cirebon Tahun 2022
#
#     1.Korban Meninggal Dunia sebanyak 201 orang
#     2.Luka berat hanya 3 orang
#     3.Kebanyakan hanya luka ringan saja berjumlah 959 orang
#     4.Kerugian Materi mencapai Rp. 1.232.051.200
#     5.Jumlah Kasus Laka Lantas Berjumlah 835 Kasus
